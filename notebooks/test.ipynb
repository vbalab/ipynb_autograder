# %%
import os

# %% [markdown]
# # Some markdown code

# %%
some_code = 2

print("some output")
# Out:
# some output

# %% [markdown]
# ## Additional markdown code

# %%
additional_code = 2

print("additional output")
# Out:
# additional output

# %% [markdown]
# # Plot

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import matplotlib.pyplot as plt
#       3 plt.figure()
#       4 plt.show()
#
# ModuleNotFoundError: No module named 'matplotlib'
