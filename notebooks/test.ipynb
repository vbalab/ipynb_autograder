# %%
import os

# %% [markdown]
# # Some markdown code

# %%
some_code = 2

print("some output")
# Out:
# some output

# %% [markdown]
# ## Second markdown code

# %%
second_code = 2

print("second output")
# Out:
# second output

# %% [markdown]
# ## Plot

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
ax.set_xlim(0, 1)
ax.set_ylim(0, 1)
plt.show()

# %% [markdown]
# ### Additional Plot

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
ax.set_xlim(0, 100)
ax.set_ylim(0, 100)
plt.show()
