# %%
import os

# %% [markdown]
# # Some markdown code

# %%
some_code = 2

print("some output")
# Out:
# some output

# %% [markdown]
# ## Additional markdown code

# %%
additional_code = 2

print("additional output")
# Out:
# additional output

# %% [markdown]
# # Plot

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
ax.set_xlim(0, 1)
ax.set_ylim(0, 1)
plt.show()
